# %%
import numpy as np
gradient = np.tile(np.arange(0, 256, dtype='uint8'), (255, 1))
gradient
# Out:
# array([[  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        ...,
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(gradient, cmap='cool', vmin=0, vmax=255)
plt.show()
